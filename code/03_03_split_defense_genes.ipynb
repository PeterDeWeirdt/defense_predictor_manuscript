# %%
import pandas as pd
from tqdm import tqdm
import os
from core import read_dom_table
import glob
import xml.etree.ElementTree as ET
import networkx as nx
from sklearn.model_selection import train_test_split

# %%
def get_xml_file_paths(top_directory):
    pattern = f"{top_directory}/**/*.xml"
    file_paths = glob.glob(pattern, recursive=True)    
    return file_paths

# %%
def get_exhchangable_profiles(file_path):
    model = os.path.basename(file_path).split('.')[0]
    tree = ET.parse(os.path.expanduser(file_path))
    root = tree.getroot()
    data = []
    exchangeable_names = []
    parent_names = []
    for gene in root.findall('.//gene'):
        gene_name = gene.attrib.get('name', '')
        exchangeables = gene.findall('.//exchangeables')
        if exchangeables:
            parent_names.append(gene_name)
            for exch in exchangeables:
                exch_genes = exch.findall('.//gene')
                for sub_gene in exch_genes:
                    exch_name = sub_gene.attrib.get('name', '')
                    data.append({'model': model, 'parent_profile': gene_name, 'profile': exch_name})
                    exchangeable_names.append(exch_name)
        data.append({'model': model, 'parent_profile': gene_name, 'profile': gene_name})
    df = pd.DataFrame(data)
    rm_exchangable = [x for x in exchangeable_names if x not in parent_names]
    df = df[~df['parent_profile'].isin(rm_exchangable)].reset_index(drop=True)
    return df

# %%
defense_finder_genes_df = pd.read_parquet('../data/interim/defense_finder_genes_genomes.pq')
defense_homolog_df = pd.read_parquet('../data/interim/defense_finder_homologs_profile_names.pq')

# %%
true_defense_seq_ids = defense_finder_genes_df['seq_id'].drop_duplicates()
print(len(true_defense_seq_ids))
defense_homolog_seq_ids = defense_homolog_df['seq_id'].drop_duplicates()
print(len(defense_homolog_seq_ids))
# Out:
# 241596
# 2272123

# %%
# %%time
seq_id_seq_df = pd.read_parquet('../data/interim/refseq_seq_ids.pq')
defense_seq_id_seq_df = seq_id_seq_df[seq_id_seq_df['seq_id'].isin(true_defense_seq_ids)]
defense_homolog_seq_id_seq_df = seq_id_seq_df[seq_id_seq_df['seq_id'].isin(defense_homolog_seq_ids)]
del seq_id_seq_df
# Out:
# CPU times: user 1min 31s, sys: 45.7 s, total: 2min 16s
# Wall time: 2min 42s

# %%
# %%time
all_clusters = pd.read_table('../data/interim/refseqs_clusters_mode1.tsv',
                             names=['cluster_id', 'seq_id'])
defense_clusters = (all_clusters[all_clusters['seq_id'].isin(true_defense_seq_ids)]
                    .reset_index(drop=True))
defense_homolog_clusters = (all_clusters[all_clusters['seq_id'].isin(defense_homolog_seq_ids)])
del all_clusters
# Out:
# CPU times: user 1min 41s, sys: 5.36 s, total: 1min 46s
# Wall time: 1min 46s

# %% [markdown]
# ## Get exchangable genes

# %%
definition_file_paths = get_xml_file_paths(os.path.expanduser('~/defense-finder-models/definitions/'))

# %%
len(definition_file_paths)
# Out:
# 229

# %%
gene_group_list = []
for f in tqdm(definition_file_paths):
    gene_group_list.append(get_exhchangable_profiles(f))
gene_group_df = pd.concat(gene_group_list)
# Out:
# 100%|██████████| 229/229 [00:02<00:00, 84.35it/s]

# %%
all_genes = gene_group_df['profile'].drop_duplicates().to_list()
len(all_genes)
# Out:
# 1018

# %%
gene_group_edges = (gene_group_df.merge(gene_group_df, how='inner', on='parent_profile')
                    .query('profile_x != profile_y')
                    [['profile_x', 'profile_y']]
                    .drop_duplicates()
                    .rename(columns={'profile_x': 'gene_name_x', 
                                     'profile_y': 'gene_name_y'}))

# %% [markdown]
# ## Get overlapping gene clusters

# %%
seq_id_gene_df = (defense_finder_genes_df[['seq_id', 'gene_name']].drop_duplicates()
                  .merge(defense_clusters, how='inner', on='seq_id'))

# %%
gene_clust_edges = (seq_id_gene_df.merge(seq_id_gene_df, how='inner', on='cluster_id')
                    .query('gene_name_x != gene_name_y')
                    [['gene_name_x', 'gene_name_y']]
                    .drop_duplicates())

# %%
gene_clust_network = nx.from_pandas_edgelist(gene_clust_edges, 'gene_name_x', 'gene_name_y')

# %%
G = nx.from_pandas_edgelist(gene_clust_edges, 'gene_name_x', 'gene_name_y')
nodes = list(G.nodes)
for gene_name in all_genes:
    if gene_name not in nodes:
        G.add_node(gene_name)
print('# Edges:', G.number_of_edges())
print('# Nodes:', G.number_of_nodes())
components = nx.connected_components(G)
component_list = []
for i, comp in enumerate(components):
    subgraph = G.subgraph(comp)
    max_degree_node = max(subgraph, key=lambda node: subgraph.degree(node))
    for name in comp:
        component_list.append({'name': name, 
                               'component': i, 
                               'component_name': max_degree_node})
print('# Components:', i)
gene_component_df = pd.DataFrame(component_list)
gene_component_df['component_name'].value_counts().head(20)
# Out:
# # Edges: 444
# # Nodes: 1018
# # Components: 703
# component_name
# Lamassu-Fam__LmuB_SMC_Cap4_nuclease_II         99
# Cas__csm3gr7_III_IV                            16
# Cas__cas5_I_9                                  13
# Cas__cas1_I_II_III_IV_V_VI_1                   13
# RosmerTA__RmrA_2662548665                      12
# Lamassu-Fam__LmuA_effector_Cap4_nuclease_II     9
# Cas__cas6_I_II_III_IV_V_VI_7                    8
# Cas__cas2_I_II_III_IV_V_VI_3                    6
# Cas__cas7_I_15                                  5
# Cas__cas8b2_I-B_2                               5
# Cas__csm6_III_3                                 5
# Cas__cse2gr11_I-E_8                             5
# Cas__cas10_III_1                                5
# Septu__PtuB                                     4
# Cas__cmr5gr11_III-B_18                          4
# Cas__csm2gr11_III-A_15                          4
# Cas__cas2_I-E_1                                 4
# Thoeris_I__ThsA_new_grand                       4
# Cas__cas5u_I-G_1                                4
# CBASS__Cyclase_II                               4
# Name: count, dtype: int64

# %% [markdown]
# ## Cluster genes

# %%
cat_edges = (pd.concat([gene_group_edges, gene_clust_edges])
             .drop_duplicates())
G = nx.from_pandas_edgelist(cat_edges, 'gene_name_x', 'gene_name_y')
nodes = list(G.nodes)
for gene_name in all_genes:
    if gene_name not in nodes:
        G.add_node(gene_name)
print('# Edges:', G.number_of_edges())
print('# Nodes:', G.number_of_nodes())
components = nx.connected_components(G)
component_list = []
for i, comp in enumerate(components):
    subgraph = G.subgraph(comp)
    max_degree_node = max(subgraph, key=lambda node: subgraph.degree(node))
    for name in comp:
        component_list.append({'name': name, 
                               'component': i, 
                               'component_name': max_degree_node})
print('# Components:', i)
gene_component_df = pd.DataFrame(component_list)
gene_component_df['component_name'].value_counts().head(20)
# Out:
# # Edges: 8524
# # Nodes: 1018
# # Components: 278
# component_name
# Lamassu-Fam__LmuB_SMC_Cap4_nuclease_II    168
# Cas__cas8b2_I-B_2                          99
# Cas__csm3gr7_III-D_3                       50
# Menshen__NsnC_2525400098                   45
# Cas__csa5gr11_III-B_1                      37
# Cas__cas5_I-A_4                            36
# RosmerTA__RmrT_2600853143                  33
# Cas__csx1_III_17                           27
# Cas__cas6_I_II_III_IV_V_VI_10              27
# Cas__cas12f1_V-F_2                         26
# Cas__cas7_I-B_1                            22
# Cas__csx22_III-A_1                         19
# Cas__csx19_III-D_18                        19
# RosmerTA__RmrA_2603008502                  16
# Cas__cas10_III-C_3                         14
# Cas__cas2_I-E_1                            13
# Cas__csn2_II-A_5                           13
# Cas__cas10d_I-D_1                           8
# Lamassu-Fam__LmuC_acc_Sir2                  8
# Cas__cas9_II-B_2                            6
# Name: count, dtype: int64

# %% [markdown]
# ## Split clusters

# %%
test_size = 0.15
val_size = 0.05
unique_components = list(gene_component_df['component_name'].unique())
train_val_components, test_components = train_test_split(unique_components, test_size=test_size, random_state=7)
train_components, val_components = train_test_split(train_val_components, test_size=val_size/(1-test_size), random_state=7)

# %%
len(val_components)/len(unique_components)
# Out:
# 0.05017921146953405

# %%
def assign_profile(component, test_components=test_components, train_components=train_components, val_components=val_components):
    if component in val_components:
        return 'val'
    elif component in test_components:
        return 'test'
    else:
        return 'train'

# %%
gene_component_df['split'] = gene_component_df['component_name'].apply(assign_profile)

# %%
gene_component_df['split'].value_counts()
# Out:
# split
# train    882
# test      99
# val       37
# Name: count, dtype: int64

# %%
gene_component_df.groupby('split')['component'].nunique()
# Out:
# split
# test      42
# train    223
# val       14
# Name: component, dtype: int64

# %%
pd.set_option('display.max_rows', 200)
gene_component_df[gene_component_df['split'] == 'test']
# Out:
#                              name  component               component_name
# 213               Wadjet__JetA_II          2              Wadjet__JetA_II  \
# 214                Wadjet__JetA_I          2              Wadjet__JetA_II
# 215              Wadjet__JetA_III          2              Wadjet__JetA_II
# 216              Wadjet__JetB_III          3             Wadjet__JetB_III
# 217                Wadjet__JetB_I          3             Wadjet__JetB_III
# 218               Wadjet__JetB_II          3             Wadjet__JetB_III
# 371         Cas__csx10gr5_III-D_5         22         Cas__csm3gr7_III-D_3
# 372           Cas__csm3gr7_III_IV         22         Cas__csm3gr7_III-D_3
# 373          Cas__cmr6gr7_III-B_2         22         Cas__csm3gr7_III-D_3
# 374          Cas__csm3gr7_III-D_5         22         Cas__csm3gr7_III-D_3
# 375            Cas__csm3gr7_III_1         22         Cas__csm3gr7_III-D_3
# 376          Cas__csm5gr7_III-A_1         22         Cas__csm3gr7_III-D_3
# 377          Cas__cmr1gr7_III-B_1         22         Cas__csm3gr7_III-D_3
# 378          Cas__csm3gr7_III-D_4         22         Cas__csm3gr7_III-D_3
# 379          Cas__cmr1gr7_III-B_4         22         Cas__csm3gr7_III-D_3
# 380         Cas__csx10gr5_III-D_4         22         Cas__csm3gr7_III-D_3
# 381    Cas__cmr1gr7_III-B_III-C_3         22         Cas__csm3gr7_III-D_3
# 382    Cas__cmr4gr7_III-B_III-C_2         22         Cas__csm3gr7_III-D_3
# 383          Cas__cmr1gr7_III-B_2         22         Cas__csm3gr7_III-D_3
# 384          Cas__cmr6gr7_III-B_3         22         Cas__csm3gr7_III-D_3
# 385          Cas__csm3gr7_III-A_1         22         Cas__csm3gr7_III-D_3
# 386          Cas__csm3gr7_III-A_2         22         Cas__csm3gr7_III-D_3
# 387         Cas__csx10gr5_III-D_2         22         Cas__csm3gr7_III-D_3
# 388          Cas__csm5gr7_III-A_4         22         Cas__csm3gr7_III-D_3
# 389    Cas__cmr3gr5_III-B_III-C_5         22         Cas__csm3gr7_III-D_3
# 390          Cas__csm5gr7_III-A_3         22         Cas__csm3gr7_III-D_3
# 391    Cas__cmr3gr5_III-B_III-C_4         22         Cas__csm3gr7_III-D_3
# 392          Cas__csm4gr5_III-A_3         22         Cas__csm3gr7_III-D_3
# 393    Cas__cmr4gr7_III-B_III-C_1         22         Cas__csm3gr7_III-D_3
# 394         Cas__csx10gr5_III-D_1         22         Cas__csm3gr7_III-D_3
# 395          Cas__cmr6gr7_III-C_1         22         Cas__csm3gr7_III-D_3
# 396    Cas__cmr3gr5_III-B_III-C_2         22         Cas__csm3gr7_III-D_3
# 397    Cas__cmr3gr5_III-B_III-C_8         22         Cas__csm3gr7_III-D_3
# 398          Cas__csm4gr5_III-D_2         22         Cas__csm3gr7_III-D_3
# 399    Cas__csm3gr7_III-A_III-D_2         22         Cas__csm3gr7_III-D_3
# 400          Cas__csm4gr5_III-A_2         22         Cas__csm3gr7_III-D_3
# 401    Cas__cmr3gr5_III-B_III-C_6         22         Cas__csm3gr7_III-D_3
# 402          Cas__csm3gr7_III-D_6         22         Cas__csm3gr7_III-D_3
# 403             Cas__cas5_III-F_1         22         Cas__csm3gr7_III-D_3
# 404          Cas__csm4gr5_III-A_1         22         Cas__csm3gr7_III-D_3
# 405          Cas__csm3gr7_III-D_3         22         Cas__csm3gr7_III-D_3
# 406          Cas__cmr3gr5_III-C_1         22         Cas__csm3gr7_III-D_3
# 407          Cas__cmr6gr7_III-B_1         22         Cas__csm3gr7_III-D_3
# 408          Cas__csm3gr7_III-D_7         22         Cas__csm3gr7_III-D_3
# 409    Cas__cmr1gr7_III-B_III-C_2         22         Cas__csm3gr7_III-D_3
# 410          Cas__cmr1gr7_III-B_5         22         Cas__csm3gr7_III-D_3
# 411          Cas__csm3gr7_III-D_2         22         Cas__csm3gr7_III-D_3
# 412          Cas__csm5gr7_III-A_2         22         Cas__csm3gr7_III-D_3
# 413          Cas__csm3gr7_III-D_1         22         Cas__csm3gr7_III-D_3
# 414    Cas__cmr3gr5_III-B_III-C_3         22         Cas__csm3gr7_III-D_3
# 415          Cas__csm4gr5_III-A_5         22         Cas__csm3gr7_III-D_3
# 416          Cas__cmr1gr7_III-C_1         22         Cas__csm3gr7_III-D_3
# 417          Cas__cmr1gr7_III-B_3         22         Cas__csm3gr7_III-D_3
# 418    Cas__cmr3gr5_III-B_III-C_1         22         Cas__csm3gr7_III-D_3
# 419         Cas__csx10gr5_III-D_3         22         Cas__csm3gr7_III-D_3
# 420   Cas__csm3gr7_III-A_III-D_10         22         Cas__csm3gr7_III-D_3
# 729            Cas__cas13d_VI-D_1         37           Cas__cas13d_VI-D_1
# 730            Cas__cas13a_VI-A_1         37           Cas__cas13d_VI-D_1
# 731            Cas__cas13c_VI-C_1         37           Cas__cas13d_VI-D_1
# 732            Cas__cas13b_VI-B_1         37           Cas__cas13d_VI-D_1
# 733            Cas__cas13b_VI-B_2         37           Cas__cas13d_VI-D_1
# 796                  DRT_3__drt3b         57                 DRT_3__drt3b
# 799                   DRT_2__drt2         60                  DRT_2__drt2
# 804                 ShosTA__ShosA         65                ShosTA__ShosA
# 805                 ShosTA__ShosT         66                ShosTA__ShosT
# 808                 PsyrTA__PsyrA         69                PsyrTA__PsyrA
# 825                   DarTG__DarG         86                  DarTG__DarG
# 827    PD-Lambda-3__PD-Lambda-3_B         88   PD-Lambda-3__PD-Lambda-3_B
# 829   Rst_2TM_1TM_TIR__Rst_TIR_tm         90  Rst_2TM_1TM_TIR__Rst_TIR_tm
# 836        AbiA_large__AbiA_large         97       AbiA_large__AbiA_large
# 837                  Rst_3HP__Hp1         98                 Rst_3HP__Hp1
# 852                    AbiC__AbiC        113                   AbiC__AbiC
# 865                    AbiV__AbiV        126                   AbiV__AbiV
# 868              PD-T4-8__PD-T4-8        129             PD-T4-8__PD-T4-8
# 871             radar_II__rdrA_II        132            radar_II__rdrA_II
# 880                   RexAB__RexB        141                  RexAB__RexB
# 884                 Gao_Mza__MzaA        145                Gao_Mza__MzaA
# 886                 Gao_Mza__MzaE        147                Gao_Mza__MzaE
# 893                  Dazbog__DzbA        154                 Dazbog__DzbA
# 899                   Aditi__DitB        160                  Aditi__DitB
# 901                  Olokun__OloB        162                 Olokun__OloB
# 903                    BREX__pglY        164                   BREX__pglY
# 910              Retron_XIII__ARM        171             Retron_XIII__ARM
# 916     Retron_IX__WHDNAB_E2F_TDP        177    Retron_IX__WHDNAB_E2F_TDP
# 926    PD-Lambda-5__PD-Lambda-5_A        187   PD-Lambda-5__PD-Lambda-5_A
# 932                     Dpd__DpdF        193                    Dpd__DpdF
# 938                     Dpd__QueC        199                    Dpd__QueC
# 962            Zorya_TypeII__ZorE        223           Zorya_TypeII__ZorE
# 965              PD-T7-5__PD-T7-5        226             PD-T7-5__PD-T7-5
# 969           Cas__PEPT_D_III-A_1        230          Cas__PEPT_D_III-A_1
# 976             Cas__cmr7_III-B_1        237            Cas__cmr7_III-B_1
# 988            PD-T4-9__PD-T4-9_A        249           PD-T4-9__PD-T4-9_A
# 996         Gao_Her_DUF__HerA_DUF        257        Gao_Her_DUF__HerA_DUF
# 998             Gao_Her_SIR__SIR2        259            Gao_Her_SIR__SIR2
# 999                    SpbK__SpbK        260                   SpbK__SpbK
# 1002           Rst_PARIS__DUF4435        263           Rst_PARIS__DUF4435
# 1005         PD-T4-10__PD-T4-10_B        266         PD-T4-10__PD-T4-10_B
# 1012                  Azaca__ZacA        273                  Azaca__ZacA
# 1013           PD-T4-2__PD-T4-2_B        274           PD-T4-2__PD-T4-2_B
#
#      split
# 213   test
# 214   test
# 215   test
# 216   test
# 217   test
# 218   test
# 371   test
# 372   test
# 373   test
# 374   test
# 375   test
# 376   test
# 377   test
# 378   test
# 379   test
# 380   test
# 381   test
# 382   test
# 383   test
# 384   test
# 385   test
# 386   test
# 387   test
# 388   test
# 389   test
# 390   test
# 391   test
# 392   test
# 393   test
# 394   test
# 395   test
# 396   test
# 397   test
# 398   test
# 399   test
# 400   test
# 401   test
# 402   test
# 403   test
# 404   test
# 405   test
# 406   test
# 407   test
# 408   test
# 409   test
# 410   test
# 411   test
# 412   test
# 413   test
# 414   test
# 415   test
# 416   test
# 417   test
# 418   test
# 419   test
# 420   test
# 729   test
# 730   test
# 731   test
# 732   test
# 733   test
# 796   test
# 799   test
# 804   test
# 805   test
# 808   test
# 825   test
# 827   test
# 829   test
# 836   test
# 837   test
# 852   test
# 865   test
# 868   test
# 871   test
# 880   test
# 884   test
# 886   test
# 893   test
# 899   test
# 901   test
# 903   test
# 910   test
# 916   test
# 926   test
# 932   test
# 938   test
# 962   test
# 965   test
# 969   test
# 976   test
# 988   test
# 996   test
# 998   test
# 999   test
# 1002  test
# 1005  test
# 1012  test
# 1013  test

# %% [markdown]
# ## Split seq ids into train/test/val

# %%
max_seqs_per_cluster = 5
filtered_defense_finder_genes = (defense_finder_genes_df
                                 .merge(defense_clusters, how='inner', 
                                        on='seq_id')
                                 .merge(gene_component_df
                                        .rename(columns={'name': 'gene_name'}), 
                                        on='gene_name')
                                 .groupby('seq_id')
                                 .sample(n=1, random_state=7)
                                 .sample(frac=1, random_state=7)  # shuffle
                                 .groupby('cluster_id')
                                 .head(max_seqs_per_cluster)
                                 .merge(defense_seq_id_seq_df, how='inner', 
                                        on='seq_id'))

# %%
assert filtered_defense_finder_genes['seq_id'].value_counts().max() == 1
assert filtered_defense_finder_genes.groupby('cluster_id')['split'].nunique().max() == 1

# %%
from IPython.display import display

# %%
for split, split_df in filtered_defense_finder_genes.groupby('split'):
    print(split)
    display(split_df['gene_name'].value_counts().head(20))
# Out:
# test
# gene_name
# Wadjet__JetB_I                720
# Wadjet__JetA_I                594
# ShosTA__ShosT                 400
# Rst_PARIS__DUF4435            376
# Cas__cmr1gr7_III-B_1          318
# Cas__csm3gr7_III-D_2          318
# ShosTA__ShosA                 302
# Wadjet__JetB_II               301
# Cas__cmr3gr5_III-B_III-C_5    293
# DRT_2__drt2                   279
# Cas__cmr6gr7_III-B_3          252
# Cas__csm3gr7_III-D_3          241
# Wadjet__JetA_II               238
# PD-Lambda-5__PD-Lambda-5_A    230
# Cas__csm5gr7_III-A_2          224
# PsyrTA__PsyrA                 220
# Cas__cmr6gr7_III-B_2          220
# Wadjet__JetA_III              217
# SpbK__SpbK                    199
# Wadjet__JetB_III              196
# Name: count, dtype: int64
# train
# gene_name
# RM_Type_IV__Type_IV_REases                7006
# RM_Type_II__Type_II_REases                4437
# RM__Type_I_S                              4199
# RM_Type_II__Type_II_MTases                3110
# RM_Type_IIG__Type_IIG                     2800
# AbiD__AbiD                                1318
# RM__Type_I_REases                         1280
# Septu__PtuA                               1252
# RloC__RloC                                1162
# Septu__PtuB                               1155
# RM__Type_I_MTases                         1103
# Shedu__SduA                                940
# Cas__cas3_I_5                              936
# Gabija__GajA                               898
# CBASS__Cyclase_II                          870
# Mokosh_TypeI__MkoA                         857
# Cas__cas2_I_II_III_IV_V_VI_3               815
# Gabija__GajB_2                             807
# Lamassu-Fam__LmuB_SMC_Cap4_nuclease_II     784
# RM_Type_III__Type_III_REases               734
# Name: count, dtype: int64
# val
# gene_name
# AbiEii__AbiEii         809
# SoFic__SoFic           573
# Cas__cas10_III-D_3     381
# Cas__cas10_III_1       343
# Kiwa__KwaA             313
# SanaTA__SanaT          306
# Cas__cas10_III-A_1     303
# SspBCDE__SspB          204
# SspBCDE__SspC          200
# PD-T4-3__PD-T4-3       137
# Druantia_III__DruH     132
# BREX__brxF             110
# Cas__cas10_III-B_12     74
# Cas__cas10_III-C_3      58
# SspBCDE__SspD           57
# Cas__cas10_III_6        56
# BREX__brxP              54
# Bunzi__BnzB             52
# Cas__csb3_I-G_1         44
# Cas__cas10d_I-D_3       42
# Name: count, dtype: int64

# %%
import pandas as pd
filtered_defense_finder_genes = pd.read_parquet('../data/interim/defense_finder_model_seqs.pq')

# %%
filtered_defense_finder_genes['split'].value_counts()
# Out:
# split
# train    99642
# test     10128
# val       4434
# Name: count, dtype: int64

# %% [markdown]
# ## Outputs

# %%
gene_component_df.to_csv('../data/interim/defense_finder_gene_split_df.csv', index=False)

# %%
filtered_defense_finder_genes.to_parquet('../data/interim/defense_finder_model_seqs.pq', index=False)
